# %% [markdown]
# ### E-commerce Customer Yearly Spending using Linear Regression
# - Conduct Data Analysis and create Linear Regression models
# - The purpose is to create Regressors that can help estimate Customer Yearly Spending from input data
#
# #### Import Libraries
# - install the required libraries and import

# %%
install.packages("psych")
install.packages("reshape2")

library(tidyverse)
library(psych)
library("reshape2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %% [markdown]
# #### Read Data
# - read CSV format text file into table

# %%
ecommerce_customers = read_csv("https://raw.githubusercontent.com/karthickai/Linear-Regression/master/Ecommerce%20Customers", show_col_types = FALSE)
head(ecommerce_customers)
# Out:
#   Email
# 1 mstephenson@fernandez.com
# 2 hduke@hotmail.com
# 3 pallen@yahoo.com
# 4 riverarebecca@gmail.com
# 5 mstephens@davidson-herman.com
# 6 alvareznancy@lucas.biz
#   Address                                                    Avatar
# 1 835 Frank Tunnel\nWrightmouth, MI 82180-9605               Violet
# 2 4547 Archer Common\nDiazchester, CA 06566-8576             DarkGreen
# 3 24645 Valerie Unions Suite 582\nCobbborough, DC 99414-7564 Bisque
# 4 1414 David Throughway\nPort Jason, OH 22070-1220           SaddleBrown
# 5 14023 Rodriguez Passage\nPort Jacobville, PR 37242-1057    MediumAquaMarine
# 6 645 Martha Park Apt. 611\nJeffreychester, MN 67218-7250    FloralWhite
#   Avg. Session Length Time on App Time on Website Length of Membership
# 1 34.49727            12.65565    39.57767        4.082621
# 2 31.92627            11.10946    37.26896        2.664034
# 3 33.00091            11.33028    37.11060        4.104543
# 4 34.30556            13.71751    36.72128        3.120179
# 5 33.33067            12.79519    37.53665        4.446308
# 6 33.87104            12.02693    34.47688        5.493507
#   Yearly Amount Spent
# 1 587.9511
# 2 392.2049
# 3 487.5475
# 4 581.8523
# 5 599.4061
# 6 637.1024

# %% [markdown]
# - the data has 8 columns in which 3 are non-numeric

# %% [markdown]
# #### Exploratory Data Analysis
#
# - ##### Univariate Analysis

# %%
sort(table(ecommerce_customers$Avatar))
# Out:
#                Azure                Coral       CornflowerBlue
#                    1                    1                    1
#          DeepSkyBlue            LawnGreen LightGoldenRodYellow
#                    1                    1                    1
#       LightSlateGray         MediumPurple          NavajoWhite
#                    1                    1                    1
#        PaleGoldenRod            PaleGreen        PaleTurquoise
#                    1                    1                    1
#           PapayaWhip           PowderBlue                  Red
#                    1                    1                    1
#               Yellow            AliceBlue                Black
#                    1                    2                    2
#           Chartreuse             DarkGray           DarkSalmon
#                    2                    2                    2
#        DarkSlateGray            FireBrick          ForestGreen
#                    2                    2                    2
#              Fuchsia            GoldenRod            IndianRed
#                    2                    2                    2
#                Ivory                Khaki            LightBlue
#                    2                    2                    2
#           LightCoral          LightYellow                Linen
#                    2                    2                    2
#         MediumOrchid              OldLace            OrangeRed
#                    2                    2                    2
#                 Peru               Silver              SkyBlue
#                    2                    2                    2
#                 Snow           Aquamarine                Beige
#                    2                    3                    3
#            BurlyWood             DarkBlue       DarkOliveGreen
#                    3                    3                    3
#           DarkOrange           DarkOrchid              DarkRed
#                    3                    3                    3
#        DarkSlateBlue        DarkTurquoise           DodgerBlue
#                    3                    3                    3
#                 Gray             Lavender            LightGray
#                    3                    3                    3
#       LightSteelBlue     MediumAquaMarine      MediumSlateBlue
#                    3                    3                    3
#            MintCream            MistyRose            RosyBrown
#                    3                    3                    3
#               Salmon             SeaShell          SpringGreen
#                    3                    3                    3
#                  Tan               Violet          YellowGreen
#                    3                    3                    3
#                 Blue            Chocolate             Cornsilk
#                    4                    4                    4
#             DarkCyan            DarkKhaki              DimGray
#                    4                    4                    4
#          FloralWhite            Gainsboro                 Gold
#                    4                    4                    4
#                Green             HoneyDew              HotPink
#                    4                    4                    4
#               Indigo        LavenderBlush            LightCyan
#                    4                    4                    4
#            LightPink        LightSeaGreen                 Lime
#                    4                    4                    4
#       MediumSeaGreen      MediumTurquoise      MediumVioletRed
#                    4                    4                    4
#         MidnightBlue        PaleVioletRed                 Pink
#                    4                    4                    4
#            RoyalBlue             SeaGreen               Sienna
#                    4                    4                    4
#            SlateGray           WhiteSmoke         AntiqueWhite
#                    4                    4                    5
#       BlanchedAlmond                Brown              Crimson
#                    5                    5                    5
#            DarkGreen          DarkMagenta           GhostWhite
#                    5                    5                    5
#         LemonChiffon           LightGreen          LightSalmon
#                    5                    5                    5
#            LimeGreen              Magenta           MediumBlue
#                    5                    5                    5
#    MediumSpringGreen                 Navy                Olive
#                    5                    5                    5
#               Orchid           SandyBrown            SteelBlue
#                    5                    5                    5
#              Thistle                White                 Aqua
#                    5                    5                    6
#               Bisque           BlueViolet        DarkGoldenRod
#                    6                    6                    6
#         DarkSeaGreen           DarkViolet             DeepPink
#                    6                    6                    6
#         LightSkyBlue             Moccasin            OliveDrab
#                    6                    6                    6
#               Orange            PeachPuff               Purple
#                    6                    6                    6
#          SaddleBrown               Tomato            Turquoise
#                    6                    6                    6
#                Wheat            CadetBlue                 Cyan
#                    6                    7                    7
#          GreenYellow            SlateBlue                 Teal
#                    7                    7                    7

# %% [markdown]
# - Avatar column has 138 unique values

# %%
describe(ecommerce_customers, omit = TRUE) # ignore non-numeric variables
# Out:
#                      vars n   mean       sd         median     trimmed
# Avg. Session Length  4    500  33.053194  0.9925631  33.082008  33.056582
# Time on App          5    500  12.052488  0.9942156  11.983231  12.057463
# Time on Website      6    500  37.060445  1.0104889  37.069367  37.054034
# Length of Membership 7    500   3.533462  0.9992775   3.533975   3.549454
# Yearly Amount Spent  8    500 499.314038 79.3147815 498.887875 499.071946
#                      mad        min         max        range      skew
# Avg. Session Length   1.0297181  29.5324290  36.139662   6.607234 -0.03198202
# Time on App           1.0124208   8.5081522  15.126994   6.618842 -0.08858708
# Time on Website       1.0251831  33.9138472  40.005182   6.091334  0.01206913
# Length of Membership  0.8850302   0.2699011   6.922689   6.652788 -0.10596926
# Yearly Amount Spent  76.8177488 256.6705823 765.518462 508.847880  0.03458172
#                      kurtosis    se
# Avg. Session Length  -0.01221977 0.04438877
# Time on App           0.09942286 0.04446267
# Time on Website      -0.12083413 0.04519044
# Length of Membership  0.32023252 0.04468905
# Yearly Amount Spent   0.43359700 3.54706486

# %% [markdown]
# - no missing values exist in data
# - most of columns mean and median are very close
# - range of Yearly Amount Spent differ from other variables a lot

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

conf <- theme_bw() +
theme(text = element_text(size=20), plot.title = element_text(hjust = 0.5))

ggplot(data = ecommerce_customers) + 
geom_histogram(mapping = aes(x = `Yearly Amount Spent`), bins = 20, color = "black", fill = "white") +
ggtitle("Distribution of customers yearly spending") + 
conf

# %% [markdown]
# - most of the customers spend around 400 - 600 per year
# - there are more customers whose yearly spending is below mean

# %% [markdown]
# - ##### Bivariate Analysis

# %%
ggplot(data = ecommerce_customers) + 
geom_point(mapping = aes(x =`Avg. Session Length`, y = `Yearly Amount Spent`), size = 4, alpha = 0.8) +
ggtitle("Average session length v.s. Yearly amount spent") + 
conf

# %%
ggplot(data = ecommerce_customers) + 
geom_point(mapping = aes(x =`Time on App`, y = `Yearly Amount Spent`), size = 4, alpha = 0.8) +
ggtitle("Time on app v.s. Yearly amount spent") + 
conf

# %%
ggplot(data = ecommerce_customers) + 
geom_point(mapping = aes(x =`Time on Website`, y = `Yearly Amount Spent`), size = 4, alpha = 0.8) +
ggtitle("Time on website v.s. Yearly amount spent") + 
conf

# %%
ggplot(data = ecommerce_customers) + 
geom_point(mapping = aes(x =`Length of Membership`, y = `Yearly Amount Spent`), size = 4, alpha = 0.8) +
ggtitle("Length of membership v.s. Yearly amount spent") + 
conf

# %% [markdown]
# - most of the variables have positive correlation with the Yearly Amount Spent
# - Length of Membership has the strongest correlation with Yearly Amount Spent
# - Time on website has very little to no correlation with Yearly Amount Spent

# %% [markdown]
# - ##### Correlation Analysis

# %%
cor_mat = cor(ecommerce_customers[, 4:ncol(ecommerce_customers)])
plot_data <- melt(round(cor_mat, 2))

options(repr.plot.width = 10, repr.plot.height = 8)

ggplot(plot_data, aes(Var1, Var2, fill = value)) + 
geom_tile() +
scale_fill_distiller(palette = "Greys", direction = 1) +
geom_text(aes(label = value), size = 8) +
xlab("Column") +
ylab("Column") +
ggtitle("Columns correlation heatmap") +
theme_bw() +
theme(text = element_text(size=20), plot.title = element_text(hjust = 0.5), axis.text.x = element_text(angle = 45, hjust = 1))

options(repr.plot.width = 10, repr.plot.height = 6)

# %% [markdown]
# - features have very low correlation with each other
# - estimation of relationship between individual feature and target is less error prone

# %% [markdown]
# #### Model Building
#
# - ##### Simple Linear Regression

# %%
mod <- lm(`Yearly Amount Spent` ~ `Length of Membership`, data = ecommerce_customers)

summary(mod)
# Out:
# Call:
# lm(formula = `Yearly Amount Spent` ~ `Length of Membership`,
#     data = ecommerce_customers)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -125.975  -29.032   -0.494   33.033  147.777
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             272.400      7.675   35.49   <2e-16 ***
# `Length of Membership`   64.219      2.090   30.72   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 46.66 on 498 degrees of freedom
# Multiple R-squared:  0.6546,	Adjusted R-squared:  0.6539
# F-statistic: 943.9 on 1 and 498 DF,  p-value: < 2.2e-16

# %% [markdown]
# - model with Length of Membership as single independent variable is better than intercept only model
# - for this data, per one unit increase in Length of Membership model give Yearly Amount Spent increased by 64.219
# - model helped capture 65% of variance in target variable

# %%
preds <- tibble(ecommerce_customers)

preds$mod1_pred = predict(mod, ecommerce_customers)
preds$mod1_res = mod$residuals

mean_mod1_res <- mean(preds$mod1_res)

ggplot(data = preds) + 
geom_point(mapping = aes(x = mod1_pred, y = mod1_res), size = 4, alpha = 0.8) +
geom_hline(yintercept = mean_mod1_res, color="red") +
xlab("Predicted") +
ylab("Residual") + 
ggtitle("Predicted Yearly Amount Spent v.s. Residual") + 
conf

# %%
ggplot(data = preds) + 
geom_point(mapping = aes(x =`Length of Membership`, y = `Yearly Amount Spent`), size = 4, alpha = 0.8) + 
geom_line(mapping = aes(x =`Length of Membership`, y = mod1_pred), col = "red") +
xlab("Length of Membership") +
ylab("Yearly Amount Spent") + 
ggtitle("Fitted model for Yearly spending using Membership length") + 
conf

# %% [markdown]
# - ##### Multiple Linear Regression

# %%
mod2 <- lm(`Yearly Amount Spent` ~ `Length of Membership` + `Time on App`, data = ecommerce_customers)

summary(mod2)
# Out:
# Call:
# lm(formula = `Yearly Amount Spent` ~ `Length of Membership` +
#     `Time on App`, data = ecommerce_customers)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -81.601 -19.447   0.732  19.492  75.657
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -181.531     15.422  -11.77   <2e-16 ***
# `Length of Membership`   63.117      1.228   51.40   <2e-16 ***
# `Time on App`            37.986      1.234   30.78   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 27.4 on 497 degrees of freedom
# Multiple R-squared:  0.8811,	Adjusted R-squared:  0.8807
# F-statistic:  1842 on 2 and 497 DF,  p-value: < 2.2e-16

# %% [markdown]
# - additional 23 % change in dependent variable can be captured after including Time on App as feature
# - the greater Length of Membership and Time on App, the higher Yearly Amount Spent
# - model cannot be used with new or no app interaction customers

# %%
preds$mod2_pred <- predict(mod2, ecommerce_customers)
preds$mod2_res <- mod2$residuals

mean_mod2_res <- mean(preds$mod2_res)

ggplot(data = preds) + 
geom_point(mapping = aes(x = mod2_pred, y = mod2_res), size = 4, alpha = 0.8) +
geom_hline(yintercept = mean_mod2_res, color="red") +
xlab("Predicted") +
ylab("Residual") + 
ggtitle("Predicted Yearly Amount Spent v.s. Residual") + 
conf

# %%
mod3 <- lm(`Yearly Amount Spent` ~ `Length of Membership` + `Time on App` + `Avg. Session Length` + `Time on Website`, data = ecommerce_customers)

summary(mod3)
# Out:
# Call:
# lm(formula = `Yearly Amount Spent` ~ `Length of Membership` +
#     `Time on App` + `Avg. Session Length` + `Time on Website`,
#     data = ecommerce_customers)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -30.4059  -6.2191  -0.1364   6.6048  30.3085
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -1051.5943    22.9925 -45.736   <2e-16 ***
# `Length of Membership`    61.5773     0.4483 137.346   <2e-16 ***
# `Time on App`             38.7092     0.4510  85.828   <2e-16 ***
# `Avg. Session Length`     25.7343     0.4510  57.057   <2e-16 ***
# `Time on Website`          0.4367     0.4441   0.983    0.326
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.973 on 495 degrees of freedom
# Multiple R-squared:  0.9843,	Adjusted R-squared:  0.9842
# F-statistic:  7766 on 4 and 495 DF,  p-value: < 2.2e-16

# %% [markdown]
# - it's unclear to conclude how Time on Website have effect on dependent variable in population level
# - model suggest that the more lengthy customer's Sessions, the higher Yearly Amount Spent is
# - model cannot be used with new or no interaction customers

# %%
preds$mod3_pred <- predict(mod3, ecommerce_customers)
preds$mod3_res <- mod3$residuals

mean_mod3_res <- mean(preds$mod3_res)

ggplot(data = preds) + 
geom_point(mapping = aes(x = mod3_pred, y = mod3_res), size = 4, alpha = 0.8) +
geom_hline(yintercept = mean_mod3_res, color="red") +
xlab("Predicted") +
ylab("Residual") + 
ggtitle("Predicted Yearly Amount Spent v.s. Residual") + 
conf

# %% [markdown]
# #### Residual Normality Test

# %%
shapiro.test(preds$mod1_res)
shapiro.test(preds$mod2_res)
shapiro.test(preds$mod3_res)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  preds$mod1_res
# W = 0.99756, p-value = 0.6837
# 	Shapiro-Wilk normality test
#
# data:  preds$mod2_res
# W = 0.99711, p-value = 0.5269
# 	Shapiro-Wilk normality test
#
# data:  preds$mod3_res
# W = 0.99782, p-value = 0.7716

# %% [markdown]
# - failed to reject the null hypothesis saying residuals come from normally distributed population
